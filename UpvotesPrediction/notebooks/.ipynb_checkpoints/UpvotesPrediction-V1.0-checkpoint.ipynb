# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
train = pd.read_csv("D:/Github/ML-Practice Problems/UpvotesPrediction/data/Train.csv")
test = pd.read_csv("D:/Github/ML-Practice Problems/UpvotesPrediction/data/Test.csv")

# %%
print("train : ",train.shape)
print("test : ",test.shape)
# Out:
# train :  (330045, 7)
# test :  (141448, 6)

# %%
print("train head :\n")
train.head()
print("test head :\n")
test.head()
# Out:
# train head :
#        ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0   52664   a      3942.0      2.0    155623   7855.0     42.0
# 1  327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2  468453   c      1358.0      4.0     56177   8067.0     60.0
# 3   96996   a       264.0      3.0    168793  27064.0      9.0
# 4  131465   c      4271.0      4.0    112223  13986.0     83.0
# test head :
#        ID Tag  Reputation  Answers  Username    Views
# 0  366953   a      5645.0      3.0     50652  33200.0
# 1   71864   c     24511.0      6.0     37685   2730.0
# 2  141692   i       927.0      1.0    135293  21167.0
# 3  316833   i        21.0      6.0    166998  18528.0
# 4  440445   i      4475.0     10.0     53504  57240.0

# %%
train.corr()
# Out:
#                   ID  Reputation   Answers  Username     Views   Upvotes
# ID          1.000000    0.008546  0.017448  0.000628  0.017400  0.006328
# Reputation  0.008546    1.000000  0.066504 -0.041019  0.036455  0.266710
# Answers     0.017448    0.066504  1.000000 -0.012197  0.498642  0.202033
# Username    0.000628   -0.041019 -0.012197  1.000000  0.002306 -0.011970
# Views       0.017400    0.036455  0.498642  0.002306  1.000000  0.437336
# Upvotes     0.006328    0.266710  0.202033 -0.011970  0.437336  1.000000

# %%
train.dtypes
train.describe()
# Out:
# ID              int64
# Tag            object
# Reputation    float64
# Answers       float64
# Username        int64
# Views         float64
# Upvotes       float64
# dtype: object
#                   ID    Reputation        Answers       Username  \
# count  330045.000000  3.300450e+05  330045.000000  330045.000000
# mean   235748.682789  7.773147e+03       3.917672   81442.888803
# std    136039.418471  2.706141e+04       3.579515   49215.100730
# min         1.000000  0.000000e+00       0.000000       0.000000
# 25%    117909.000000  2.820000e+02       2.000000   39808.000000
# 50%    235699.000000  1.236000e+03       3.000000   79010.000000
# 75%    353620.000000  5.118000e+03       5.000000  122559.000000
# max    471493.000000  1.042428e+06      76.000000  175738.000000
#
#               Views        Upvotes
# count  3.300450e+05  330045.000000
# mean   2.964507e+04     337.505358
# std    8.095646e+04    3592.441135
# min    9.000000e+00       0.000000
# ...

# %%
train.corr().style.background_gradient(cmap='Blues').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_4f3e22f6_ce53_11e9_999b_b88a60aed10brow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4f3e22f6_ce53_11e9_999b_b88a60aed10brow0_col1 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_4f3e22f6_ce53_11e9_999b_b88a60aed10brow0_col2 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_4f3e22f6_ce53_11e9_999b_b88a60aed10brow0_col3 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_4f3e22f6_ce53_11e9_999b_b88a60aed10brow0_col4 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_4f3e22f6_ce53_11e9_999b_b88a60aed10brow0_col5 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_4f3e22f6_ce53_11e9_999b_b88a60aed10brow1_col0 {
#             background-color:  #f5fafe;
#             color:  #000000;
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330045 entries, 0 to 330044
# Data columns (total 7 columns):
# ID            330045 non-null int64
# Tag           330045 non-null object
# Reputation    330045 non-null float64
# Answers       330045 non-null float64
# Username      330045 non-null int64
# Views         330045 non-null float64
# Upvotes       330045 non-null float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 17.6+ MB

# %%
sns.boxplot(train['Views'])

# %%
plt.figure(figsize = (10, 6))
ax = sns.boxplot(x='Tag', y='Upvotes', data=train)

# %%
train['Tag'].value_counts().plot.bar(title='Freq dist of Marketing Type')

# %%
pd.pivot_table(train, values='Upvotes',columns=['Tag'], aggfunc=np.sum)
# Out:
# Tag               a           c          h          i           j          o  \
# Upvotes  10030204.0  23735061.0  7911376.0  3803327.0  39031622.0  1631440.0
#
# Tag               p         r          s          x
# Upvotes  17681927.0  983257.0  5528283.0  1055459.0

# %%
train.groupby('Tag').sum()
# Out:
#               ID   Reputation   Answers    Username         Views     Upvotes
# Tag
# a     7593816254  192235503.0  134995.0  2583026785  1.007930e+09  10030204.0
# c    17242903650  765621708.0  293288.0  5820910505  1.938011e+09  23735061.0
# h     4868872841  143641023.0   77708.0  1684883235  6.981264e+08   7911376.0
# i     7139769457  169739851.0  119224.0  2559542029  5.121364e+08   3803327.0
# j    17174193224  598480239.0  314011.0  5913012003  3.127011e+09  39031622.0
# o     3437495852   82283167.0   49175.0  1156647123  1.964386e+08   1631440.0
# p    10328753013  349949536.0  172633.0  3683183737  1.440461e+09  17681927.0
# r     2938692924   65821690.0   28670.0  1058198964  1.497153e+08    983257.0
# s     5428705885  152664466.0   83983.0  1848251740  6.018986e+08   5528283.0
# x     1654470911   45051052.0   19321.0   572162114  1.124802e+08   1055459.0
